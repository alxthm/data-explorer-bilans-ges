# %%
import pandas as pd
import hvplot.pandas
import plotly.express as px
import panel as pn
import numpy as np
import holoviews as hv

hv.extension('matplotlib')
hv.extension('bokeh')

pd.options.plotting.backend = 'holoviews'

# %config Completer.use_jedi = False

# to remove the warning https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
pd.options.mode.copy_on_write = True

# to make plotly work in jupyter lab (https://github.com/plotly/plotly_express/issues/38#issuecomment-826602624)
import plotly.io as pio
pio.renderers.default='iframe'

# happens when doing operations with all the columns
# https://stackoverflow.com/questions/51521526/python-pandas-how-to-supress-performancewarning
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="db291c7b-7ac5-43ca-83d7-c9736efe125d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
from src.app import pane
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d9583202-7957-4037-b902-0c4f8e24a6c8'>
#   <div id="d5fffcad-7318-413e-8113-8394e84fc82e" data-root-id="d9583202-7957-4037-b902-0c4f8e24a6c8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
pane
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] WidgetBox
#             [0] Select(name='Indicateur', options=['emissions_par_salarie', ...], value='emissions_par_salarie')
#             [1] Select(name='Mode de consolidation', options=['all', 'Opérationnel', ...], value='all')
#             [2] Select(name='Année de reporting', options=['all', 2009, ...], value='all')
#         [1] Column
#             [0] Column
#                 [0] Markdown(str)
#                 [1] ParamFunction(function, _pane=HoloViews, defer_load=False)
#             [1] Column
#                 [0] Markdown(str)
#                 [1] Select(name="Secteur d'activité", options=['all', "Activités financi...], value='all')
#                 [2] ParamFunction(function, _pane=HoloViews, defer_load=False)
#     [2] Markdown(str)
